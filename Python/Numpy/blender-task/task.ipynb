# %%
import numpy as np

# %%
test1 = rng.integers(0, 100, size=40)

# %%
test1 = np.where(test1 > 90, 100)
test1 = np.where(test1 < 55, 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 test1 = np.where(test1 > 90, 100)
#       2 test1 = np.where(test1 < 55, 0)
#
# ValueError: either both or neither of x and y should be given
