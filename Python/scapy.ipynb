# %%
from scapy.all import *

# %%
p=IP()/UDP()/DNS()

# %%
p[IP].dst = "8.8.8.8"

# %%
p[DNSQR].qname = "www.one.co.il."

# %%
p[UDP].sport = 5555
p[UDP].dport = 53

# %%
res = sr1(p)
# Out:
# Begin emission
# ...
# Finished sending 1 packets
# *
# Received 4 packets, got 1 answers, remaining 0 packets

# %%
print(res[DNSRR].rdata)
# Out:
# b'one.co.il.'

# %%
res.show()
# Out:
# ###[ IP ]###
#   version   = 4
#   ihl       = 5
#   tos       = 0x0
#   len       = 322
#   id        = 64894
#   flags     =
#   frag      = 0
#   ttl       = 60
#   proto     = udp
#   chksum    = 0x9d81
#   src       = 8.8.8.8
#   dst       = 10.99.200.56
#   \options   \
# ###[ UDP ]###
#      sport     = domain
#      dport     = personal_agent
#      len       = 302
#      chksum    = 0x942
# ###[ DNS ]###
#         id        = 0
#         qr        = 1
#         opcode    = QUERY
#         aa        = 0
#         tc        = 0
#         rd        = 1
#         ra        = 1
#         z         = 0
#         ad        = 0
#         cd        = 0
#         rcode     = ok
#         qdcount   = 1
#         ancount   = 5
#         nscount   = 5
#         arcount   = 5
#         \qd        \
#          |###[ DNS Question Record ]###
#          |  qname     = b'www.one.co.il.'
#          |  qtype     = A
#          |  unicastresponse= 0
#          |  qclass    = IN
#         \an        \
#          |###[ DNS Resource Record ]###
#          |  rrname    = b'www.one.co.il.'
#          |  type      = CNAME
#          |  cacheflush= 0
#          |  rclass    = IN
#          |  ttl       = 223
#          |  rdlen     = None
#          |  rdata     = b'one.co.il.'
#          |###[ DNS Resource Record ]###
#          |  rrname    = b'one.co.il.'
#          |  type      = A
#          |  cacheflush= 0
#          |  rclass    = IN
#          |  ttl       = 103
#          |  rdlen     = None
#          |  rdata     = 13.35.78.36
#          |###[ DNS Resource Record ]###
#          |  rrname    = b'one.co.il.'
#          |  type      = A
#          |  cacheflush= 0
#          |  rclass    = IN
#          |  ttl       = 103
#          |  rdlen     = None
#          |  rdata     = 13.35.78.33
#          |###[ DNS Resource Record ]###
#          |  rrname    = b'one.co.il.'
#          |  type      = A
#          |  cacheflush= 0
#          |  rclass    = IN
#          |  ttl       = 103
#          |  rdlen     = None
#          |  rdata     = 13.35.78.19
#          |###[ DNS Resource Record ]###
#          |  rrname    = b'one.co.il.'
#          |  type      = A
#          |  cacheflush= 0
#          |  rclass    = IN
#          |  ttl       = 103
#          |  rdlen     = None
#          |  rdata     = 13.35.78.25
#         \ns        \
#          |###[ DNS Resource Record ]###
#          |  rrname    = b'one.co.il.'
#          |  type      = NS
#          |  cacheflush= 0
#          |  rclass    = IN
#          |  ttl       = 5040
#          |  rdlen     = None
#          |  rdata     = b'ns4.dnsmadeeasy.com.'
#          |###[ DNS Resource Record ]###
#          |  rrname    = b'one.co.il.'
#          |  type      = NS
#          |  cacheflush= 0
#          |  rclass    = IN
#          |  ttl       = 5040
#          |  rdlen     = None
#          |  rdata     = b'ns1.dnsmadeeasy.com.'
#          |###[ DNS Resource Record ]###
#          |  rrname    = b'one.co.il.'
#          |  type      = NS
#          |  cacheflush= 0
#          |  rclass    = IN
#          |  ttl       = 5040
#          |  rdlen     = None
#          |  rdata     = b'ns0.dnsmadeeasy.com.'
#          |###[ DNS Resource Record ]###
#          |  rrname    = b'one.co.il.'
#          |  type      = NS
#          |  cacheflush= 0
#          |  rclass    = IN
#          |  ttl       = 5040
#          |  rdlen     = None
#          |  rdata     = b'ns3.dnsmadeeasy.com.'
#          |###[ DNS Resource Record ]###
#          |  rrname    = b'one.co.il.'
#          |  type      = NS
#          |  cacheflush= 0
#          |  rclass    = IN
#          |  ttl       = 5040
#          |  rdlen     = None
#          |  rdata     = b'ns2.dnsmadeeasy.com.'
#         \ar        \
#          |###[ DNS Resource Record ]###
#          |  rrname    = b'ns4.dnsmadeeasy.com.'
#          |  type      = A
#          |  cacheflush= 0
#          |  rclass    = IN
#          |  ttl       = 82638
#          |  rdlen     = None
#          |  rdata     = 208.80.127.2
#          |###[ DNS Resource Record ]###
#          |  rrname    = b'ns1.dnsmadeeasy.com.'
#          |  type      = A
#          |  cacheflush= 0
#          |  rclass    = IN
#          |  ttl       = 172177
#          |  rdlen     = None
#          |  rdata     = 208.80.124.2
#          |###[ DNS Resource Record ]###
#          |  rrname    = b'ns0.dnsmadeeasy.com.'
#          |  type      = A
#          |  cacheflush= 0
#          |  rclass    = IN
#          |  ttl       = 82559
#          |  rdlen     = None
#          |  rdata     = 208.94.148.2
#          |###[ DNS Resource Record ]###
#          |  rrname    = b'ns3.dnsmadeeasy.com.'
#          |  type      = A
#          |  cacheflush= 0
#          |  rclass    = IN
#          |  ttl       = 172177
#          |  rdlen     = None
#          |  rdata     = 208.80.125.2
#          |###[ DNS Resource Record ]###
#          |  rrname    = b'ns2.dnsmadeeasy.com.'
#          |  type      = A
#          |  cacheflush= 0
#          |  rclass    = IN
#          |  ttl       = 172177
#          |  rdlen     = None
#          |  rdata     = 208.80.126.2

# %%
for i in range(res[DNS].ancount):
        print(res[DNSRR][i].rdata)
