# %%
from scapy.all import *

# %%
data = sniff(count=10)

# %%
def is_dns(p):
    if DNS in p:
        if p[DNS].qr == 1:
            return True
    return False

def prn_ip(p):
    
    print("\n")

# %%
sniff(count = 10, lfilter = is_dns, prn = prn_ip)
# Out:
# ip: 13.89.179.14
#
#
# ip: 13.89.179.14
#
#
# ip: 23.58.193.190
#
#
# ip: 23.58.193.190
#
#
# ip: 23.58.193.190
#
#
# ip: 23.58.193.190
#
#
# ip: 23.58.193.190
# <Sniffed: TCP:0 UDP:10 ICMP:0 Other:0>
